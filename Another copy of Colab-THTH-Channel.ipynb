# %% [markdown]
# # 📚 Follow me on Youtube for more: [TinHocThucHanh1984 channel](https://youtube.com/@tinhocthuchanh1984)

# %% [markdown]
# # Part 1️⃣: [Mount Google Drive in Google Colab](https://www.youtube.com/watch?v=6vbe7KeEtoE)

# %%
from google.colab import drive
drive.mount('drive')

# %% [markdown]
# # Part 2️⃣: Mount OneDrive to Google Colab
# 1.   Set Default browser
# 2.   Sign into your OneDrive account
# 3. Download Rclone: https://rclone.org/downloads/
# 4. Unzip rclone.zip
# 5. Open up the Terminal or the CMD from the start if you're using Windows and terminal if you're using MacOS or Linux
# - 5.1. Windows: Open CMD from start menu; Follow one command from video; ⬛      rclone.exe authorize "onedrive"
# - 5.2. Mac & Linux: Open Terminal; Follow one command from video; ⬛ sudo chmod +x rclone; ⬛ ./rclone authorize "onedrive"
# 6. Now it will open up the link in your browser (you have to sign in into your microsoft)
# 7. So you have successfully got the code in the cmd or terminal
# 8. Download & Install Latest Setup in colab: https://rclone.org/downloads/

# %%
# !wget https://downloads.rclone.org/v1.53.2/rclone-v1.53.2-linux-amd64.deb
# !apt install ./rclone-v1.53.2-linux-amd64.deb

# %% [markdown]
# 9. Authenticate One Drive
#
#
# *   Type: n
# *   Type the name: OneDrive
# * Type 23 (onedrive is listed it's in the number 23)
# * Now press Enter, Enter again two times
# * Type: n
# * Now you have to paste the code copy from CMD or Terminal
# * You have to choose the number 1
# * Type: 0 (We have the drive listed here)
# * Type: y
# * Type: q

# %%
# !rclone config

# %% [markdown]
# 10. Mount OneDrive

# %%
# !sudo mkdir /content/onedrive
# !nohup rclone --vfs-cache-mode writes mount onedrive: /content/onedrive &

# %% [markdown]
# # Part 3️⃣: Mount Mega in Google Colab

# %% [markdown]
# 1. Download & Install Latest Setup in colab: https://rclone.org/downloads/

# %%
# !wget https://downloads.rclone.org/v1.53.2/rclone-v1.53.2-linux-amd64.deb
# !apt install ./rclone-v1.53.2-linux-amd64.deb

# %% [markdown]
# 2. Authenticate Mega
# *   Type: n  (New Remote)
# *   Type the name: Mega
# * Type 21 (Mega is listed it's in the number 21)
# * Type email@gmail (User name)
# * Type: y (Yes type in my own password)
# * Enter the password:
# * Type: n (Edit advanced config?)
# * Type: y (Yes this is OK (default))
# * Type: q (Quit config)

# %%
# !rclone config

# %% [markdown]
# 3. Mount Mega

# %%
# !sudo mkdir /content/mega
# !nohup rclone --vfs-cache-mode writes mount mega: /content/mega &

# %% [markdown]
# # Part 4️⃣: Mount Dropbox in Google Colab
# 1.   Sign into your Dropbox account
# 2. Open up the Terminal or the CMD from the start if you're using Windows and terminal if you're using MacOS or Linux
# - 2.1. Windows: Open CMD from start menu; Follow one command from video; ⬛      rclone authorize "dropbox"
# - 2.2. Mac & Linux: Open Terminal; Follow one command from video; ⬛ sudo chmod +x rclone; ⬛ ./rclone authorize "onedrive"
# 3. Now it will open up the link in your browser (you have to sign in into your Dropbox)
# 4. So you have successfully got the code in the cmd or terminal
# 5. Download & Install Latest Setup in colab: https://rclone.org/downloads/

# %%
# !wget https://downloads.rclone.org/v1.53.2/rclone-v1.53.2-linux-amd64.deb
# !apt install ./rclone-v1.53.2-linux-amd64.deb

# %% [markdown]
# 6. Authenticate Dropbox
#
#
# *   Type: n
# *   Type the name: Dropbox
# * Type 23 (dropbox is listed it's in the number 23)
# * Now press Enter, Enter again two times
# * Type: n
# * Now you have to paste the code copy from CMD or Terminal
# * You have to choose the number 1
# * Type: 0 (We have the drive listed here)
# * Type: y
# * Type: q

# %%
# !rclone config

# %% [markdown]
# 7. Mount Dropbox

# %%
# !sudo mkdir /content/dropbox
# !nohup rclone --vfs-cache-mode writes mount dropbox: /content/dropbox &

# %% [markdown]
# # Part 5️⃣: Sync between Cloud Storage Easily

# %%
# !sudo cp -av "/content/drive/My Drive/Office"   "/content/drive/Shared drives/TeamDrive"

# %%
# !sudo mv -v "/content/drive/MyDrive/Office" "/content/drive/Shareddrives/TeamDrive1"

# %%
# !ls  "/path"

# %% [markdown]
# # Part 6️⃣: Compress Files/Folders to .rar Archives in Google Drive & other Clouds

# %% [markdown]
# 1️⃣ install rar

# %%
# !apt-get install rar

# %% [markdown]
# 2️⃣ Compress Files/Folders:
# * !sudo rar a -ep1 "/path/Test.rar" -p"password" -r "/path/File or Folder"  -v"1024000" -z -df
# ___
# * a : Add files to archive; File save path after compression .RAR
# * -p : Set a compressed password
# * -r : The path to the file, folder to be compressed
# * -v<size>[k,b]  Create volumes with size=<size>*1000 [*1024, *1]
# * -z : Write comments archived from the file
# * -df : Delete files after archiving
# * No -ep, -ep1 is full path
# * -ep: Compress files without full path
# * -ep1: Compress files without full path1 , lay ten Folder cuoi cung
# * Sử dụng mẫu này để add thêm file vào file.rar hiện có

# %%
# !sudo rar a -ep1 "/content/onedrive/DATAcompress.rar" -p"" -r "/content/onedrive/DATA" -z -v"200"

# %% [markdown]
# 3️⃣ Add archive comment; Write archive comment to file
# * !sudo rar cw "/path/compresss.rar"
# * c : Add archive comment
# * cw : Write archive comment to file

# %%
# !sudo rar c "/content/mega/macospicture.rar"

# %% [markdown]
# 4️⃣ List archive contents [technical[all], bare]
# * !sudo rar  l[t[a],b] "/path/comprossed.rar"

# %%
# !sudo rar l[t[a],b] "/content/mega/macospicture.rar"

# %% [markdown]
# # Part 7️⃣: Extract .Rar Files in Google Drive and other Clouds

# %% [markdown]
# ▶️ !sudo unrar x -p "" -n "/path/comprossed.rar" "Target Folder Location"
# ___
# * x : Extract files with full path
# * e : Extract files without archived paths
# * -p : Set password
# * -n : Additionally filter included files

# %%
# !sudo unrar x -p "" -n "/content/mega/macospicture.rar"  "/content/mega/unrar"

# %% [markdown]
# # Part 8️⃣: Compress Files/Folders .Zip Archives in Google Drive & other Clouds

# %% [markdown]
# 1️⃣ Compress Files/Folders .Zip
# * !cd "drive/My Drive" && zip "/path/compress.zip"  -r "./folder or file"

# %%
# !cd "drive/My Drive" && zip "/content/drive/My Drive/DATAcompress.zip"  -r "./TAMVIET/Phần mềm hiện FILE ẩn"

# %%
# !cd "/content/drive/My Drive" && zip -e"7" "/content/drive/My Drive/333.zip"  -r "./Test/123"

# %% [markdown]
# 2️⃣ List archive contents
# * !sudo unzip   -l "/content/drive/My Drive/123/abc2.zip"

# %%
# !sudo unzip   -l "/content/drive/My Drive/DATAcompress.zip"

# %% [markdown]
# 3️⃣ Update file to compress.zip
# * !cd "drive/My Drive" && zip "compress.zip"   -u "fileupdate"

# %%
# !cd "drive/My Drive" && zip "/content/drive/My Drive/DATAcompress.zip"   -u "./macOS-Big-Sur-Control-Center.jpg"

# %% [markdown]
# # Part 9️⃣: Extract .Zip Files in Google Drive and other Clouds

# %% [markdown]
# * !cd "drive/My Drive" && unzip "/content/drive/My Drive/compress.zip" -d "/content/drive/My Drive/Test/"

# %%
# !cd "drive/My Drive" && unzip "/content/drive/My Drive/DATAcompress.zip" -d "/content/drive/My Drive"

# %% [markdown]
# # Part 🔟: Download link URL to Clouds

# %%
# !sudo cp -v -r -n "/content/drive2/Video Course RAR" "/content/drive/Shareddrives/Team Drive 2"
